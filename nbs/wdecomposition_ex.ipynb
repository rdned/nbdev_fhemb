# %%
#| default_exp wdecomposition_ex

# %% [markdown]
# # Reconstruct Embedding

# %%
#| eval: false
from nbdev_fhemb.decomposeEmb_ex import percentile_emb_decomp, percentile_emb

# %% [markdown]
# ## Create Reconstruction Embeddings

# %% [markdown]
# #### `Wdecompostion.create_reconstrction` returns an `Embeddiong` object

# %%
#| eval: false

percentile_emb_rec = percentile_emb_decomp.create_wreconstruction(  # reconstruct a signal from specified frequency bands (fbands)
    subjs=[(40, 42), 50],                                           # Subjects to project the reconstruction for: may be specified as intervals, e.g., [(40, 42)]
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[(40, 42), 50], args=() and kwargs={}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 50, 65, 66, 67, 68]
#  [DEBUG] mixins.wrapper: Calling: create_wreconstruction with subjs=[40, 41, 42, 50] and args=() and kwargs={}
#  [DEBUG] mixins.wrapper: Calling create_wreconstruction with subjs=[40, 41, 42, 50] and args=() and kwargs={}
#  [INFO] mixins.get_fbands: Take all available frequency bands: [(0, 0.05), (0.05, 0.1), (0.1, 0.2), (0.2, 0.39), (0.39, 0.78), (0.78, 1.56), (1.56, 3.12), (3.12, 6.25), (6.25, 12.5)]
#  [DEBUG] wdecomposition.create_wreconstruction: Calling create_wreconstruction with bands: [0, 1, 2, 3, 4, 5, 6, 7, 8] and subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] tutils.create: Creating wreconstruct with args: (0, 1, 2, 3, 4, 5, 6, 7, 8) and kwargs: dict_keys(['factory', 'subjects'])
# ...

# %%
#| eval: false

percentile_emb_rec234 = percentile_emb_decomp.create_wreconstruction(  # reconstruct a signal from specified frequency bands (fbands)
    subjs=[(40, 42), 50],                                              # Subjects to project the reconstruction for: may be specified as intervals, e.g., [(40, 42)]
    fbands=[2,3,4]                                                     # frequency band to include in the reconstruction (default is 'all') 
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[(40, 42), 50], args=() and kwargs={'fbands': [2, 3, 4]}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 50, 65, 66, 67, 68]
#  [DEBUG] mixins.wrapper: Calling: create_wreconstruction with subjs=[40, 41, 42, 50] and args=() and kwargs={'fbands': [2, 3, 4]}
#  [DEBUG] mixins.wrapper: Calling create_wreconstruction with subjs=[40, 41, 42, 50] and args=() and kwargs={'fbands': [2, 3, 4]}
#  [DEBUG] wdecomposition.create_wreconstruction: Calling create_wreconstruction with bands: [2, 3, 4] and subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] tutils.create: Creating wreconstruct with args: (2, 3, 4) and kwargs: dict_keys(['factory', 'subjects'])
#  [DEBUG] tutils.create: Using already calculated value for (2, 3, 4)

# %% [markdown]
# ## Inspect the Metadata
# > use methods provided by `Embedding` class

# %% [markdown]
# ##### The reconstructed embedding has the same 3 features as the embedding it is reconstructed from

# %%
#| eval: false

percentile_emb_decomp.features
# Out:
# ('p0', 'p50', 'p90')

# %%
#| eval: false

percentile_emb_rec234.features
# Out:
# ('p0', 'p50', 'p90')

# %% [markdown]
# ##### We have projected out most of the subjects in the reconstructed embedding

# %%
#| eval: false

percentile_emb_decomp.subjects
# Out:
# ['subj40',
#  'subj41',
#  'subj42',
#  'subj50',
#  'subj65',
#  'subj66',
#  'subj67',
#  'subj68']

# %%
#| eval: false

percentile_emb_rec234.subjects
# Out:
# ['subj41', 'subj42', 'subj50', 'subj40']

# %% [markdown]
# #### We have chosen 2nd, 3rd and 4th frequency band

# %%
#| eval: false

percentile_emb_decomp.frequencies
# Out:
# [(0, 0.05),
#  (0.05, 0.1),
#  (0.1, 0.2),
#  (0.2, 0.39),
#  (0.39, 0.78),
#  (0.78, 1.56),
#  (1.56, 3.12),
#  (3.12, 6.25),
#  (6.25, 12.5)]

# %%
#| eval: false

percentile_emb_rec234.frequencies
# Out:
# [(0.1, 0.78)]

# %%
#| eval: false

percentile_emb_decomp.periods
# Out:
# [(20.48, 'inf'),
#  (10.24, 20.48),
#  (5.12, 10.24),
#  (2.56, 5.12),
#  (1.28, 2.56),
#  (0.64, 1.28),
#  (0.32, 0.64),
#  (0.16, 0.32),
#  (0.08, 0.16)]

# %%
#| eval: false

percentile_emb_rec234.periods
# Out:
# [(1.28, 10.24)]

# %% [markdown]
# ## Plot the Signals

# %% [markdown]
# ##### The original signal

# %%
#| eval: false

percentile_emb.plot_signal( 
    subjs=[41],    # subjects to plot the signals for
    feature='p50'  # features, i.e., embedding components
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[41], args=() and kwargs={'feature': 'p50'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 50, 65, 66, 67, 68]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[41] and args=() and kwargs={'feature': 'p50'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[41] and args=() and kwargs={'feature': 'p50'}
# (<Figure size 1200x200 with 1 Axes>,
#  [<Axes: title={'center': 'subj41: Frequency interval All Hz, period interval All s'}>])

# %% [markdown]
# ##### The reconstructed signal

# %%
#| eval: false

percentile_emb_rec.plot_signal(
    subjs=[41],    # subjects to plot the signals for
    feature='p50'  # features, i.e., embedding components
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[41], args=() and kwargs={'feature': 'p50'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [41, 42, 50, 40]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[41] and args=() and kwargs={'feature': 'p50'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[41] and args=() and kwargs={'feature': 'p50'}
# (<Figure size 1200x200 with 1 Axes>,
#  [<Axes: title={'center': "subj41: Frequency interval [(0, 12.5)] Hz, period interval [(0.08, 'inf')] s"}>])

# %% [markdown]
# #### PArtially reconstructed signal

# %%
#| eval: false

percentile_emb_rec234.plot_signal(
    feature='p50'  # features, i.e., embedding components
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=all, args=() and kwargs={'feature': 'p50'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [41, 42, 50, 40]
#  [DEBUG] mixins.wrapper: Taking all subjects: [41, 42, 50, 40]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[41, 42, 50, 40] and args=() and kwargs={'feature': 'p50'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[41, 42, 50, 40] and args=() and kwargs={'feature': 'p50'}
# (<Figure size 1200x800 with 4 Axes>,
#  [<Axes: title={'center': 'subj40: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>,
#   <Axes: title={'center': 'subj41: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>,
#   <Axes: title={'center': 'subj42: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>,
#   <Axes: title={'center': 'subj50: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>])
