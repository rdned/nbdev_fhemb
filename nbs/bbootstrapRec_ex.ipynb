# %%
#| default_exp bbootstrapRec_ex

# %% [markdown]
# # Block Bootstrap `Embedding`s of Wavelet-based Subbands
# > Any `Embedding` object can be block bootstrapped into another `Embedding` object

# %% [markdown]
# ::: {.callout-note}
# Note that `EmbeddingCollection` invokes `.plot_signal` and `.bbootstrap` methods through its [Dynamic Attribute Forwarding](embeddingColl.ipynb#dynamic-attribute-access).
# :::

# %% [markdown]
# ## The Bootstrapped Signal

# %%
#| eval: false

from nbdev_fhemb.wreconstruction_ex import pca_emb_prj_decomp_rec, emb_prj_decomp_rec1

# %%
#| eval: false

pca_emb_prj_decomp_rec.plot_signal(
    subjs=[40,41],  # specify subject(s) to plot: may be specified also as intervals, e.g., [(40, 45), 47]
    feature='pc0'   # specify feature to plot: principal components are prefixed by 'pc' 
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [WARNING] py.warnings._showwarnmsg: /Users/radned/Projects/GitHub/fhemb/src/fhemb/embedding.py:576: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# (<Figure size 1200x400 with 2 Axes>,
#  [<Axes: title={'center': 'subj40: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>,
#   <Axes: title={'center': 'subj41: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>])

# %%
#| eval: false

emb_prj_decomp_rec1.plot_signal(
    subjs=[40,41],  # specify subject(s) to plot: may be specified also as intervals, e.g., [(40, 45), 47]
    feature='pc0'   # specify feature to plot: principal components are prefixed by 'pc'
)
# Out:
#  [DEBUG] embedding.__getattr__: Accessing attribute/method 'plot_signal' across embeddings: found in ['percentiles_ts', 'binheights_ts', 'pcomponents_ts']
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
# {'pcomponents_ts': (<Figure size 1200x400 with 2 Axes>,
#   [<Axes: title={'center': 'subj40: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>,
#    <Axes: title={'center': 'subj41: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>])}

# %% [markdown]
# ## Bootstrap with Different Block Lengths
# >Here we demonstrate the bootstrap method, applied to an `Embedding` and to an `EmbeddingCollection` respectively.

# %%
#| eval: false

pca_emb_prj_decomp_rec.bbootstrap(
    block_length=5,  # specify the length of the block in the block bootstrap
    rseed=0,         # random seed for reproducibility
).plot_signal(
    subjs=[40,41],   # specify subject(s) to plot: may be specified also as intervals, e.g., [(40, 45), 47]
    feature='pc0'    # specify feature to plot: principal components are prefixed by 'pc' 
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=all, args=() and kwargs={'block_length': 5, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Taking all subjects: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Calling: bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 5, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Calling bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 5, 'rseed': 0}
#  [DEBUG] embedding.bbootstrap: Calling bbootstrap with subjs=['subj40', 'subj41', 'subj42', 'subj50'], err_ts=None, block_length=5, max_level=8, rseed=0
#  [DEBUG] embedding.bbootstrap: block_length = 5, self.periods = [(1.28, 10.24)]
#  [DEBUG] embedding.bbootstrap: num_frames: 1000, block_length: 5
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 0, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 126, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 252, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 378, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 504, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 630, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 755, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 881, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 999, max_idx: 127
#  [DEBUG] embedding.bbootstrap: Block bootstrapping completed: 1000 frames, (4, 2, 1000) subjects-features-frames, 2 features
#  [DEBUG] embedding.__init__: Creating a BaseEmbedding with time_interval=(14200, 15200), subjects=['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Features setted explicitely: ('pc0', 'pc1')
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Getting subjects_int from self.subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
# (<Figure size 1200x400 with 2 Axes>,
#  [<Axes: title={'center': 'subj40: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>,
#   <Axes: title={'center': 'subj41: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>])

# %%
#| eval: false

emb_prj_decomp_rec1.bbootstrap(
    block_length=5,  # specify the length of the block in the block bootstrap
    rseed=0,         # random seed for reproducibility
).plot_signal(
    subjs=[40,41],  # specify subject(s) to plot: may be specified also as intervals, e.g., [(40, 45), 47]
    feature='pc0'   # specify feature to plot: principal components are prefixed by 'pc'
)
# Out:
#  [DEBUG] embedding.__getattr__: Accessing attribute/method 'bbootstrap' across embeddings: found in ['percentiles_ts', 'binheights_ts', 'pcomponents_ts']
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=all, args=() and kwargs={'block_length': 5, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Taking all subjects: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Calling: bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 5, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Calling bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 5, 'rseed': 0}
#  [DEBUG] embedding.bbootstrap: Calling bbootstrap with subjs=['subj40', 'subj41', 'subj42', 'subj50'], err_ts=None, block_length=5, max_level=8, rseed=0
#  [DEBUG] embedding.bbootstrap: block_length = 5, self.periods = [(1.28, 10.24)]
#  [DEBUG] embedding.bbootstrap: num_frames: 1000, block_length: 5
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 0, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 126, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 252, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 378, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 504, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 630, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 755, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 881, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 999, max_idx: 127
#  [DEBUG] embedding.bbootstrap: Block bootstrapping completed: 1000 frames, (4, 2, 1000) subjects-features-frames, 2 features
#  [DEBUG] embedding.__init__: Creating a BaseEmbedding with time_interval=(14200, 15200), subjects=['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Features setted explicitely: ('p0', 'p100')
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=all, args=() and kwargs={'block_length': 5, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Taking all subjects: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Calling: bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 5, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Calling bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 5, 'rseed': 0}
#  [DEBUG] embedding.bbootstrap: Calling bbootstrap with subjs=['subj40', 'subj41', 'subj42', 'subj50'], err_ts=None, block_length=5, max_level=8, rseed=0
#  [DEBUG] embedding.bbootstrap: block_length = 5, self.periods = [(1.28, 10.24)]
#  [DEBUG] embedding.bbootstrap: num_frames: 1000, block_length: 5
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 0, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 126, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 252, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 378, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 504, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 630, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 755, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 881, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 999, max_idx: 127
#  [DEBUG] embedding.bbootstrap: Block bootstrapping completed: 1000 frames, (4, 11, 1000) subjects-features-frames, 11 features
#  [DEBUG] embedding.__init__: Creating a BaseEmbedding with time_interval=(14200, 15200), subjects=['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Features setted explicitely: ('bh0', 'bh1', 'bh2', 'bh3', 'bh4', 'bh5', 'bh6', 'bh7', 'bh8', 'bh9', 'bh10')
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=all, args=() and kwargs={'block_length': 5, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Taking all subjects: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Calling: bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 5, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Calling bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 5, 'rseed': 0}
#  [DEBUG] embedding.bbootstrap: Calling bbootstrap with subjs=['subj40', 'subj41', 'subj42', 'subj50'], err_ts=None, block_length=5, max_level=8, rseed=0
#  [DEBUG] embedding.bbootstrap: block_length = 5, self.periods = [(1.28, 10.24)]
#  [DEBUG] embedding.bbootstrap: num_frames: 1000, block_length: 5
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 0, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 126, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 252, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 378, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 504, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 630, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 755, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 881, max_idx: 127
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 999, max_idx: 127
#  [DEBUG] embedding.bbootstrap: Block bootstrapping completed: 1000 frames, (4, 2, 1000) subjects-features-frames, 2 features
#  [DEBUG] embedding.__init__: Creating a BaseEmbedding with time_interval=(14200, 15200), subjects=['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Features setted explicitely: ('pc0', 'pc1')
#  [DEBUG] embedding.wrapper: Creating EmbeddingCollection from bbootstrap outputs: dict_keys(['percentiles_ts', 'binheights_ts', 'pcomponents_ts'])
#  [DEBUG] embedding.__getattr__: Accessing attribute/method 'plot_signal' across embeddings: found in ['percentiles_ts', 'binheights_ts', 'pcomponents_ts']
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Getting subjects_int from self.subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Getting subjects_int from self.subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Getting subjects_int from self.subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
# {'pcomponents_ts': (<Figure size 1200x400 with 2 Axes>,
#   [<Axes: title={'center': 'subj40: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>,
#    <Axes: title={'center': 'subj41: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>])}

# %%
#| eval: false

pca_emb_prj_decomp_rec.bbootstrap(
    block_length=10, # specify the length of the block in the block bootstrap
    rseed=0,         # random seed for reproducibility
).plot_signal(
    subjs=[40,41],   # specify subject(s) to plot: may be specified also as intervals, e.g., [(40, 45), 47]
    feature='pc0'    # specify feature to plot: principal components are prefixed by 'pc' 
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=all, args=() and kwargs={'block_length': 10, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Taking all subjects: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Calling: bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 10, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Calling bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 10, 'rseed': 0}
#  [DEBUG] embedding.bbootstrap: Calling bbootstrap with subjs=['subj40', 'subj41', 'subj42', 'subj50'], err_ts=None, block_length=10, max_level=8, rseed=0
#  [DEBUG] embedding.bbootstrap: block_length = 10, self.periods = [(1.28, 10.24)]
#  [DEBUG] embedding.bbootstrap: num_frames: 1000, block_length: 10
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 0, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 251, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 502, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 753, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 999, max_idx: 252
#  [DEBUG] embedding.bbootstrap: Block bootstrapping completed: 1000 frames, (4, 2, 1000) subjects-features-frames, 2 features
#  [DEBUG] embedding.__init__: Creating a BaseEmbedding with time_interval=(14200, 15200), subjects=['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Features setted explicitely: ('pc0', 'pc1')
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Getting subjects_int from self.subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
# (<Figure size 1200x400 with 2 Axes>,
#  [<Axes: title={'center': 'subj40: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>,
#   <Axes: title={'center': 'subj41: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>])

# %%
#| eval: false

emb_prj_decomp_rec1.bbootstrap(
    block_length=10, # specify the length of the block in the block bootstrap
    rseed=0,         # random seed for reproducibility
).plot_signal(
    subjs=[40,41],   # specify subject(s) to plot: may be specified also as intervals, e.g., [(40, 45), 47]
    feature='pc0'    # specify feature to plot: principal components are prefixed by 'pc'
)
# Out:
#  [DEBUG] embedding.__getattr__: Accessing attribute/method 'bbootstrap' across embeddings: found in ['percentiles_ts', 'binheights_ts', 'pcomponents_ts']
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=all, args=() and kwargs={'block_length': 10, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Taking all subjects: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Calling: bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 10, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Calling bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 10, 'rseed': 0}
#  [DEBUG] embedding.bbootstrap: Calling bbootstrap with subjs=['subj40', 'subj41', 'subj42', 'subj50'], err_ts=None, block_length=10, max_level=8, rseed=0
#  [DEBUG] embedding.bbootstrap: block_length = 10, self.periods = [(1.28, 10.24)]
#  [DEBUG] embedding.bbootstrap: num_frames: 1000, block_length: 10
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 0, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 251, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 502, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 753, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 999, max_idx: 252
#  [DEBUG] embedding.bbootstrap: Block bootstrapping completed: 1000 frames, (4, 2, 1000) subjects-features-frames, 2 features
#  [DEBUG] embedding.__init__: Creating a BaseEmbedding with time_interval=(14200, 15200), subjects=['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Features setted explicitely: ('p0', 'p100')
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=all, args=() and kwargs={'block_length': 10, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Taking all subjects: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Calling: bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 10, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Calling bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 10, 'rseed': 0}
#  [DEBUG] embedding.bbootstrap: Calling bbootstrap with subjs=['subj40', 'subj41', 'subj42', 'subj50'], err_ts=None, block_length=10, max_level=8, rseed=0
#  [DEBUG] embedding.bbootstrap: block_length = 10, self.periods = [(1.28, 10.24)]
#  [DEBUG] embedding.bbootstrap: num_frames: 1000, block_length: 10
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 0, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 251, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 502, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 753, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 999, max_idx: 252
#  [DEBUG] embedding.bbootstrap: Block bootstrapping completed: 1000 frames, (4, 11, 1000) subjects-features-frames, 11 features
#  [DEBUG] embedding.__init__: Creating a BaseEmbedding with time_interval=(14200, 15200), subjects=['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Features setted explicitely: ('bh0', 'bh1', 'bh2', 'bh3', 'bh4', 'bh5', 'bh6', 'bh7', 'bh8', 'bh9', 'bh10')
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=all, args=() and kwargs={'block_length': 10, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Taking all subjects: [41, 42, 40, 50]
#  [DEBUG] mixins.wrapper: Calling: bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 10, 'rseed': 0}
#  [DEBUG] mixins.wrapper: Calling bbootstrap with subjs=[41, 42, 40, 50] and args=() and kwargs={'block_length': 10, 'rseed': 0}
#  [DEBUG] embedding.bbootstrap: Calling bbootstrap with subjs=['subj40', 'subj41', 'subj42', 'subj50'], err_ts=None, block_length=10, max_level=8, rseed=0
#  [DEBUG] embedding.bbootstrap: block_length = 10, self.periods = [(1.28, 10.24)]
#  [DEBUG] embedding.bbootstrap: num_frames: 1000, block_length: 10
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 0, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 251, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 502, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 753, max_idx: 252
#  [WARNING] embedding.bbootstrap: num_frames: 1000, k: 999, max_idx: 252
#  [DEBUG] embedding.bbootstrap: Block bootstrapping completed: 1000 frames, (4, 2, 1000) subjects-features-frames, 2 features
#  [DEBUG] embedding.__init__: Creating a BaseEmbedding with time_interval=(14200, 15200), subjects=['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] embedding.__init__: Features setted explicitely: ('pc0', 'pc1')
#  [DEBUG] embedding.wrapper: Creating EmbeddingCollection from bbootstrap outputs: dict_keys(['percentiles_ts', 'binheights_ts', 'pcomponents_ts'])
#  [DEBUG] embedding.__getattr__: Accessing attribute/method 'plot_signal' across embeddings: found in ['percentiles_ts', 'binheights_ts', 'pcomponents_ts']
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Getting subjects_int from self.subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Getting subjects_int from self.subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Getting subjects_int from self.subjects: ['subj40', 'subj41', 'subj42', 'subj50']
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc0'}
# {'pcomponents_ts': (<Figure size 1200x400 with 2 Axes>,
#   [<Axes: title={'center': 'subj40: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>,
#    <Axes: title={'center': 'subj41: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>])}
