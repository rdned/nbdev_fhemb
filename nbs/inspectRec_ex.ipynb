# %% [markdown]
# # Inspect `Embedding`s of Wavelet-based Subbands

# %% [markdown]
# ## Inspect the Metadata
# > use methods provided by `Embedding` class

# %% [markdown]
# ### Features

# %%
#| eval: false
from nbdev_fhemb.wreconstruction_ex import emb_prj_decomp_rec1
# Out:
# DEBUG:fhemb.config.settings:Loading environment from /Users/radned/.config/fhemb/.env.paths
# DEBUG:fhemb.config.settings:Loading environment from /Users/radned/.config/fhemb/.env.db
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[(40, 44), (47, 52), 53, 54, (56, 71), (73, 75)], args=() and kwargs={'title': 'Don Giovanni', 'time_interval': (14200, 15200)}
#  [DEBUG] mixins.wrapper: Calling: get_piece_attribute_values with title=Don Giovanni and atributes=['number_of_subjects']
#  [DEBUG] mixins.wrapper: to get subjects_int from 'number_of_subjects' record in performance_library
#  [DEBUG] mixins.wrapper: Calling: __init__ with subjs=[40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75] and args=() and kwargs={'title': 'Don Giovanni', 'time_interval': (14200, 15200)}
#  [DEBUG] piece.__init__: Processed subjects: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
#  [DEBUG] piece.__init__: Compact numeric subjects: [(40, 44), (47, 54), (56, 71), (73, 75)]
#  [INFO] piece._load_from_db: Loading face_t from the database
#  [INFO] piece._fetch_from_DB: Fetching data by query SELECT subj40, subj41, subj42, subj43, subj44, subj47, subj48, subj49, subj50, subj51, subj52, subj53, subj54, subj56, subj57, subj58, subj59, subj60, subj61, subj62, subj63, subj64, subj65, subj66, subj67, subj68, subj69, subj70, subj71, subj73, subj74, subj75 FROM dg.faceposition_t WHERE frame_number >= 14200 AND frame_number < 15200 ORDER BY frame_number
# /Users/radned/.pyenv/versions/p311.fhemb/lib/python3.11/site-packages/paramiko/pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   "cipher": algorithms.TripleDES,
# /Users/radned/.pyenv/versions/p311.fhemb/lib/python3.11/site-packages/paramiko/transport.py:253: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   "class": algorithms.TripleDES,
# 2026-04-07 21:59:21,118| ERROR   | Could not connect to gateway 10.96.1.70:22 : Unable to connect to 10.96.1.70: [Errno 65] No route to host
#  [ERROR] sshtunnel.SSHTunnelForwarder._create_tunnels: Could not connect to gateway 10.96.1.70:22 : Unable to connect to 10.96.1.70: [Errno 65] No route to host
#  [ERROR] piece.prop: Error loading face_t: Could not establish session to SSH gateway
# ---------------------------------------------------------------------------
# BaseSSHTunnelForwarderError               Traceback (most recent call last)
# Cell In[2], line 2
#       1 #| eval: false
# ----> 2 from nbdev_fhemb.wreconstruction_ex import emb_prj_decomp_rec1
#
# File ~/Projects/GitHub/nbdev_fhemb/nbdev_fhemb/wreconstruction_ex.py:10
#       6 __all__ = ['percentile_emb_prj_decomp_rec', 'pca_emb_prj_decomp_rec', 'bin_emb_prj_decomp_rec', 'emb_prj_decomp_rec1']
#       8 # %% ../nbs/wreconstruction_ex.ipynb #e6c5f78e
#       9 #| eval: false
# ---> 10 from .decomposeEmb_ex import percentile_emb_decomp
#      12 # %% ../nbs/wreconstruction_ex.ipynb #f7f4f7a7
#      13 #| eval: false
#      14 percentile_emb_prj_decomp_rec = percentile_emb_decomp.create_wreconstruction( # reconstruct a signal from specified frequency bands (fbands)
#      15     subjs=[(40, 44), (47,52), 53, 54, (56, 71), (73, 75)],                    # Subjects to project the reconstruction for:specified as intervals, e.g., (40, 44)
#      16     fbands=[2,3,4]                                                            # frequency bands to include in the reconstruction (default is 'all')
#      17 )
#
# File ~/Projects/GitHub/nbdev_fhemb/nbdev_fhemb/decomposeEmb_ex.py:21
#      14 wavelet_factory = wfactory(
#      15     'db4',       # The type of wavelet to use: 'db4' is Daubechies wavelet transform of order 4. Other options include "db2", "sym2", "coif1", etc.
#      16     8            # The number of decomposition levels
#      17 )
#      19 # %% ../nbs/decomposeEmb_ex.ipynb #4e921a13
#      20 #| eval: false
# ---> 21 from .embedding_ex import percentile_emb
#      23 # %% ../nbs/decomposeEmb_ex.ipynb #e1dfedd4
#      24 #| eval: false
#      25 percentile_emb_decomp = percentile_emb.create_wdecomposition(  # decompose to frequency bands of the wavelet transform specified by 'factory'
#      26     features=['p0', 'p50', 'p90'],                             # specify features of interest: percentiles are prefixed by 'p' and may be specified also as intervals, e.g., [('p0, 'p20)]
#      27     factory=wavelet_factory                                    # specify the wavelet transform for the decomposition
#      28 )
#
# File ~/Projects/GitHub/nbdev_fhemb/nbdev_fhemb/embedding_ex.py:14
#      10 from .datasource_ex import dg0, pca
#      12 # %% ../nbs/embedding_ex.ipynb #ef3f4d26
#      13 #| eval: false
# ---> 14 pca_emb = dg0.face_t.create_pca_embedding(   # embed into principal components
#      15     factory=pca                              # specify PCA factory to use for creating the PCA embedding (imported)
#      16 )[0]                                         # the function 'create_pca_embedding' return a tuple (Embedding, ...)
#      18 percentile_emb = dg0.face_t.percentiles_ts   # embed into percentiles
#      20 bin_emb = dg0.face_t.binheights_ts           # embed into bin heights
#
# File ~/Projects/GitHub/fhemb/src/fhemb/dbms/db.py:152, in auto_properties.<locals>.create_property.<locals>.prop(self)
#     150 if name not in self._attribute_cache:
#     151     try:
# --> 152         cls.load_attribute(self, name)
#     153     except Exception as e:
#     154         logger.error(
#     155             f"Error loading {name}: {e}",
#     156             stacklevel=2,
#     157         )
#
# File ~/Projects/GitHub/fhemb/src/fhemb/dbms/db.py:1563, in DBGateway.load_attribute(cls, self, name)
#    1560 @classmethod
#    1561 def load_attribute(cls, self, name):
#    1562     """Load an attribute from the database or derive it from other attributes."""
# -> 1563     self._cache_attribute(name, self._load_from_db(name))
#
# File ~/Projects/GitHub/fhemb/src/fhemb/dbms/db.py:1611, in DBGateway._load_from_db(self, name)
#    1607 # if name == 'faceposition_t':
#    1608 query_faceposition = f"SELECT {', '.join(self.subjects)} FROM {DB_SCHEMA}.{'faceposition_t'} WHERE frame_number >= {self.time_interval[0]} AND frame_number < {self.time_interval[1]} ORDER BY frame_number"
#    1609 dict_of_matrices = {
#    1610     k: np.stack(w, axis=1)
# -> 1611     for k, w in self.__class__._fetch_from_DB(query_faceposition).items()
#    1612 }
#    1613 # return Embedding(self.time_interval, dict_of_matrices, piece_attributes=self.piece_attributes)
#    1614 # roi_t, facebbox_t - ts of matrices whose shape is a function of time/frames
#    1615 return Datasource(
#    1616     self.time_interval,
#    1617     self.__class__._fetch_from_DB(query),
#    1618     piece_attributes=self.piece_attributes,
#    1619     position=dict_of_matrices,
#    1620 )
#
# File ~/Projects/GitHub/fhemb/src/fhemb/dbms/db.py:1583, in DBGateway._fetch_from_DB(cls, query)
#    1577 logger.info(f"Fetching data by query {query}")
#    1579 db_connection = DBConnection(
#    1580     _LazyServerParams(),
#    1581     database_config=cls.database_config,
#    1582 )
# -> 1583 db_connection.start()
#    1584 try:
#    1585     data = db_connection.fetch_timeseries(query)
#
# File ~/Projects/GitHub/fhemb/src/fhemb/dbms/db.py:353, in DBConnection.start(self)
#     350 from sshtunnel import SSHTunnelForwarder
#     352 self.server = SSHTunnelForwarder(**self.server_params)
# --> 353 self.server.start()
#     354 logger.debug("SSH tunnel established")
#     355 self.effective_db_params = {
#     356     **base_db_params,
#     357     "host": "127.0.0.1",
#     358     "port": self.server.local_bind_port,
#     359 }
#
# File ~/.pyenv/versions/p311.fhemb/lib/python3.11/site-packages/sshtunnel.py:1331, in SSHTunnelForwarder.start(self)
#    1329 self._create_tunnels()
#    1330 if not self.is_active:
# -> 1331     self._raise(BaseSSHTunnelForwarderError,
#    1332                 reason='Could not establish session to SSH gateway')
#    1333 for _srv in self._server_list:
#    1334     thread = threading.Thread(
#    1335         target=self._serve_forever_wrapper,
#    1336         args=(_srv, ),
#    1337         name='Srv-{0}'.format(address_to_str(_srv.local_port))
#    1338     )
#
# File ~/.pyenv/versions/p311.fhemb/lib/python3.11/site-packages/sshtunnel.py:1174, in SSHTunnelForwarder._raise(self, exception, reason)
#    1172 def _raise(self, exception=BaseSSHTunnelForwarderError, reason=None):
#    1173     if self._raise_fwd_exc:
# -> 1174         raise exception(reason)
#    1175     else:
#    1176         self.logger.error(repr(exception(reason)))
#
# BaseSSHTunnelForwarderError: Could not establish session to SSH gateway

# %% [markdown]
# ##### Features of the reconstructed `EmbeddingCollection`

# %%
#| eval: false
emb_prj_decomp_rec1.features
# Out:
#  [DEBUG] embedding.__getattr__: Accessing attribute/method 'features' across embeddings: found in ['percentiles_ts', 'binheights_ts', 'pcomponents_ts']
# {'percentiles_ts': ('p0', 'p100'),
#  'binheights_ts': ('bh0',
#   'bh1',
#   'bh2',
#   'bh3',
#   'bh4',
#   'bh5',
#   'bh6',
#   'bh7',
#   'bh8',
#   'bh9',
#   'bh10'),
#  'pcomponents_ts': ('pc0', 'pc1')}

# %% [markdown]
# ##### The reconstructed embedding has the same features as the embedding it is reconstructed from

# %%
#| eval: false
from nbdev_fhemb.decomposeEmb_ex import percentile_emb_decomp

# %%
#| eval: false

percentile_emb_decomp.features
# Out:
# ('p0', 'p50', 'p90')

# %%
#| eval: false
from nbdev_fhemb.wreconstruction_ex import percentile_emb_prj_decomp_rec

# %%
#| eval: false

percentile_emb_prj_decomp_rec.features
# Out:
# ('p0', 'p50', 'p90')

# %% [markdown]
# ### Subjects

# %% [markdown]
# ##### Subjects of the reconstructed `EmbeddingCollection`

# %%
#| eval: false
emb_prj_decomp_rec1.subjects
# Out:
#  [DEBUG] embedding.__getattr__: Accessing attribute/method 'subjects' across embeddings: found in ['percentiles_ts', 'binheights_ts', 'pcomponents_ts']
# {'percentiles_ts': ['subj65',
#   'subj70',
#   'subj40',
#   'subj54',
#   'subj66',
#   'subj41',
#   'subj56',
#   'subj75',
#   'subj67',
#   'subj60',
#   'subj42',
#   'subj64',
#   'subj44',
#   'subj69',
#   'subj62',
#   'subj58',
#   'subj48',
#   'subj51',
#   'subj61',
#   'subj68',
#   'subj49',
#   'subj53',
#   'subj57',
#   'subj59',
#   'subj43',
#   'subj52',
#   'subj50',
#   'subj71',
#   'subj74',
#   'subj73',
#   'subj63',
#   'subj47'],
#  'binheights_ts': ['subj65',
#   'subj70',
#   'subj40',
#   'subj54',
#   'subj66',
#   'subj41',
#   'subj56',
#   'subj75',
#   'subj67',
#   'subj60',
#   'subj42',
#   'subj64',
#   'subj44',
#   'subj69',
#   'subj62',
#   'subj58',
#   'subj48',
#   'subj51',
#   'subj61',
#   'subj68',
#   'subj49',
#   'subj53',
#   'subj57',
#   'subj59',
#   'subj43',
#   'subj52',
#   'subj50',
#   'subj71',
#   'subj74',
#   'subj73',
#   'subj63',
#   'subj47'],
#  'pcomponents_ts': ['subj65',
#   'subj70',
#   'subj40',
#   'subj54',
#   'subj66',
#   'subj41',
#   'subj56',
#   'subj75',
#   'subj67',
#   'subj60',
#   'subj42',
#   'subj64',
#   'subj44',
#   'subj69',
#   'subj62',
#   'subj58',
#   'subj48',
#   'subj51',
#   'subj61',
#   'subj68',
#   'subj49',
#   'subj53',
#   'subj57',
#   'subj59',
#   'subj43',
#   'subj52',
#   'subj50',
#   'subj71',
#   'subj74',
#   'subj73',
#   'subj63',
#   'subj47']}

# %% [markdown]
# ##### We have projected out most of the subjects in the reconstructed embedding

# %%
#| eval: false

percentile_emb_decomp.subjects
# Out:
# ['subj40',
#  'subj41',
#  'subj42',
#  'subj43',
#  'subj44',
#  'subj47',
#  'subj48',
#  'subj49',
#  'subj50',
#  'subj51',
#  'subj52',
#  'subj53',
#  'subj54',
#  'subj56',
#  'subj57',
#  'subj58',
#  'subj59',
#  'subj60',
#  'subj61',
#  'subj62',
#  'subj63',
#  'subj64',
#  'subj65',
#  'subj66',
#  'subj67',
#  'subj68',
#  'subj69',
#  'subj70',
#  'subj71',
#  'subj73',
#  'subj74',
#  'subj75']

# %%
#| eval: false
percentile_emb_prj_decomp_rec.subjects
# Out:
# ['subj65',
#  'subj70',
#  'subj40',
#  'subj54',
#  'subj66',
#  'subj41',
#  'subj56',
#  'subj75',
#  'subj67',
#  'subj60',
#  'subj42',
#  'subj64',
#  'subj44',
#  'subj69',
#  'subj62',
#  'subj58',
#  'subj48',
#  'subj51',
#  'subj61',
#  'subj68',
#  'subj49',
#  'subj53',
#  'subj57',
#  'subj59',
#  'subj43',
#  'subj52',
#  'subj50',
#  'subj71',
#  'subj74',
#  'subj73',
#  'subj63',
#  'subj47']

# %% [markdown]
# ### Frequencies
# > We have chosen 2nd, 3rd and 4th frequency band

# %% [markdown]
# ##### Frequencies of the reconstructed `EmbeddingCollection`

# %%
#| eval: false
emb_prj_decomp_rec1.frequencies
# Out:
#  [DEBUG] embedding.__getattr__: Accessing attribute/method 'frequencies' across embeddings: found in ['percentiles_ts', 'binheights_ts', 'pcomponents_ts']
# {'percentiles_ts': [(0.1, 0.78)],
#  'binheights_ts': [(0.1, 0.78)],
#  'pcomponents_ts': [(0.1, 0.78)]}

# %% [markdown]
# ##### Frequencies of the frequency bands of the used wavelet transformation can be reviewed in the `Wdecomposition` object

# %%
#| eval: false

percentile_emb_decomp.frequencies
# Out:
# [(0, 0.05),
#  (0.05, 0.1),
#  (0.1, 0.2),
#  (0.2, 0.39),
#  (0.39, 0.78),
#  (0.78, 1.56),
#  (1.56, 3.12),
#  (3.12, 6.25),
#  (6.25, 12.5)]

# %% [markdown]
# ##### Frequencies of the wavelet band-interval reconstruction

# %%
#| eval: false

percentile_emb_prj_decomp_rec.frequencies
# Out:
# [(0.1, 0.78)]

# %% [markdown]
# ### Periods

# %% [markdown]
# ##### Frequencies of the reconstructed `EmbeddingCollection`

# %%
#| eval: false
emb_prj_decomp_rec1.periods
# Out:
#  [DEBUG] embedding.__getattr__: Accessing attribute/method 'periods' across embeddings: found in ['percentiles_ts', 'binheights_ts', 'pcomponents_ts']
# {'percentiles_ts': [(1.28, 10.24)],
#  'binheights_ts': [(1.28, 10.24)],
#  'pcomponents_ts': [(1.28, 10.24)]}

# %% [markdown]
# ##### Periods of the frequency bands of the used wavelet transformation can be reviewed in the `Wdecomposition` object

# %%
#| eval: false

percentile_emb_decomp.periods
# Out:
# [(20.48, 'inf'),
#  (10.24, 20.48),
#  (5.12, 10.24),
#  (2.56, 5.12),
#  (1.28, 2.56),
#  (0.64, 1.28),
#  (0.32, 0.64),
#  (0.16, 0.32),
#  (0.08, 0.16)]

# %% [markdown]
# ##### Periods of the wavelet band-interval reconstruction

# %%
#| eval: false

percentile_emb_prj_decomp_rec.periods
# Out:
# [(1.28, 10.24)]

# %% [markdown]
# ::: {.callout-note}
#   All the `Embedding`s in the `EmbeddingCollection` have the same subjects, frequencies, and periods. This is always the case if the `EmbeddingCollection` is created by `Datasource.project` method.
# :::

# %% [markdown]
# ## Plot the Signals

# %% [markdown]
# ##### The original signal

# %%
#| eval: false
from nbdev_fhemb.embedding_ex import percentile_emb

# %%
#| eval: false

percentile_emb.plot_signal( 
    subjs=[41],    # subjects to plot the signals for
    feature='p50'  # features, i.e., embedding components
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[41], args=() and kwargs={'feature': 'p50'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[41] and args=() and kwargs={'feature': 'p50'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[41] and args=() and kwargs={'feature': 'p50'}
#  [WARNING] py.warnings._showwarnmsg: /Users/radned/Projects/GitHub/fhemb/src/fhemb/embedding.py:576: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# (<Figure size 1200x200 with 1 Axes>,
#  [<Axes: title={'center': 'subj41: Frequency interval All Hz, period interval All s'}>])

# %% [markdown]
# ##### The reconstructed signal

# %%
#| eval: false

percentile_emb_prj_decomp_rec.plot_signal(
    subjs=[41],    # subjects to plot the signals for
    feature='p0'  # features, i.e., embedding components
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[41], args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [65, 70, 40, 54, 66, 41, 56, 75, 67, 60, 42, 64, 44, 69, 62, 58, 48, 51, 61, 68, 49, 53, 57, 59, 43, 52, 50, 71, 74, 73, 63, 47]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[41] and args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[41] and args=() and kwargs={'feature': 'p0'}
# (<Figure size 1200x200 with 1 Axes>,
#  [<Axes: title={'center': 'subj41: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>])

# %% [markdown]
# ##### Partially reconstructed signal

# %%
#| eval: false

percentile_emb_prj_decomp_rec.plot_signal(
    subj=[40, 41],    # subjects to plot the signals for
    feature='p0'  # features, i.e., embedding components
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #| eval: false
# ----> 3 percentile_emb_prj_decomp_rec.plot_signal(
#       4     subj=[40, 41],    # subjects to plot the signals for
#       5     feature='p0'  # features, i.e., embedding components
#       6 )
#
# NameError: name 'percentile_emb_prj_decomp_rec' is not defined

# %% [markdown]
# ##### The reconstructed signal is also available in the `EmbeddingCollection` object

# %%
#| eval: false
emb_prj_decomp_rec1.plot_signal(
    subjs=[41],    # subjects to plot the signals for
    feature='p0'  # features, i.e., embedding components
)
# Out:
#  [DEBUG] embedding.__getattr__: Accessing attribute/method 'plot_signal' across embeddings: found in ['percentiles_ts', 'binheights_ts', 'pcomponents_ts']
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[41], args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [65, 70, 40, 54, 66, 41, 56, 75, 67, 60, 42, 64, 44, 69, 62, 58, 48, 51, 61, 68, 49, 53, 57, 59, 43, 52, 50, 71, 74, 73, 63, 47]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[41] and args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[41] and args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[41], args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [65, 70, 40, 54, 66, 41, 56, 75, 67, 60, 42, 64, 44, 69, 62, 58, 48, 51, 61, 68, 49, 53, 57, 59, 43, 52, 50, 71, 74, 73, 63, 47]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[41] and args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[41] and args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[41], args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [65, 70, 40, 54, 66, 41, 56, 75, 67, 60, 42, 64, 44, 69, 62, 58, 48, 51, 61, 68, 49, 53, 57, 59, 43, 52, 50, 71, 74, 73, 63, 47]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[41] and args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[41] and args=() and kwargs={'feature': 'p0'}
# {'percentiles_ts': (<Figure size 1200x200 with 1 Axes>,
#   [<Axes: title={'center': 'subj41: Frequency interval [(0.1, 0.78)] Hz, period interval [(1.28, 10.24)] s'}>])}
