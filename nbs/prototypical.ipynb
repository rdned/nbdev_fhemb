# %% [markdown]
# # Prototypical Networks

# %%
#| hide

from nbdev.showdoc import show_doc

# %%
#| eval: false
from fhemb.utils.cutils import train_prototypical_network, evaluate_prototypical_network, calc_prototype_accuracy
# Out:
# /Users/radned/.pyenv/versions/p311.fhemb/lib/python3.11/site-packages/threadpoolctl.py:1226: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)
# DEBUG:fhemb.config.settings:Loading environment from /Users/radned/.config/fhemb/.env.paths
# DEBUG:fhemb.config.settings:Loading environment from /Users/radned/.config/fhemb/.env.db
#  [DEBUG] cutils.<module>: ROOT: /Users/radned/Projects/ttsembedding/

# %%
#| eval: false
show_doc(calc_prototype_accuracy)
# Out:
# /Users/radned/.pyenv/versions/p311.fhemb/lib/python3.11/site-packages/fastcore/docscrape.py:259: UserWarning: Unknown section Data Split
#   else: warn(msg)
# /Users/radned/.pyenv/versions/p311.fhemb/lib/python3.11/site-packages/fastcore/docscrape.py:259: UserWarning: Unknown section Example
#   else: warn(msg)
# def calc_prototype_accuracy(
#     X0:ndarray, # Time series data for class 0 of shape (n_samples, n_timesteps) or (n_samples, n_features, n_timesteps).
#     X1:ndarray, # Time series data for class 1 of same shape as X0.
#     num_epochs:int=10, # Number of training epochs for each random state.
#     lr:float=0.001, # Learning rate for optimization.
#     opt_alg:str='adamw', # Optimization algorithm ('adam', 'adamw', 'sgd').
#     random_states:int=1, # Number of random train-test-validation splits.
# )->list: # List of accuracy values, one for each random state. Each accuracy is between 0 and 1.
# """
# ...
