# %%
#| default_exp inspectEmb_ex

# %%
#| eval: false
from nbdev_fhemb.embedding_ex import dg0, pca, percentile_emb, bin_emb, pca_emb, combined_emb0, combined_emb1
# Out:
# DEBUG:fhemb.config.settings:Loading environment from /Users/radned/.config/fhemb/.env.paths
# DEBUG:fhemb.config.settings:Loading environment from /Users/radned/.config/fhemb/.env.db
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[(40, 44), (47, 52), 53, 54, (56, 71), (73, 75)], args=() and kwargs={'title': 'Don Giovanni', 'time_interval': (14200, 15200)}
#  [DEBUG] mixins.wrapper: Calling: get_piece_attribute_values with title=Don Giovanni and atributes=['number_of_subjects']
#  [DEBUG] mixins.wrapper: to get subjects_int from 'number_of_subjects' record in performance_library
#  [DEBUG] mixins.wrapper: Calling: __init__ with subjs=[40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75] and args=() and kwargs={'title': 'Don Giovanni', 'time_interval': (14200, 15200)}
# ...

# %% [markdown]
# # Inspect Embeddings

# %% [markdown]
# ::: {.callout-note}
# Note that `EmbeddingCollection` invokes `.get_ts_subjs`, `.binedges`, `.plot_signal` methods through its [Dynamic Attribute Forwarding](embeddingColl.ipynb#dynamic-attribute-access).
# :::

# %% [markdown]
# ## The Numeric Data

# %% [markdown]
# #### A request for a single percentile returns a Pandas dataframe

# %%
#| eval: false

percentile_emb.get_ts_subjs('p55')   # percentiles are prefixed by 'p'
# Out:
#  [DEBUG] embedding.get_ts_subjs: Getting time series for subjects for features p55
#  [DEBUG] embedding.get_ts_subjs: Available features: ['p0', 'p5', 'p10', 'p15', 'p20', 'p25', 'p30', 'p35', 'p40', 'p45', 'p50', 'p55', 'p60', 'p65', 'p70', 'p75', 'p80', 'p85', 'p90', 'p95', 'p100']
#         subj40     subj41     subj42     subj43     subj44     subj47  \
# 0    31.506458  32.125240  31.800814  32.560140  32.786428  32.909038
# 1    31.182337  32.105428  31.784720  32.560905  32.789658  32.899582
# 2    31.189138  32.117085  31.717500  32.548653  32.789658  32.895798
# 3    31.190339  32.105816  31.722616  32.549036  32.774844  32.896744
# 4    31.185738  32.120969  31.737957  32.544440  32.771424  32.897689
# ..         ...        ...        ...        ...        ...        ...
# 995  31.781578  32.151637  31.801207  32.846565  32.790037  32.948723
# 996  31.785505  32.152024  31.802384  32.838985  32.808260  32.952688
# ...

# %%
#| eval: false

combined_emb0.get_ts_subjs('p55')
# Out:
#  [DEBUG] embedding.__getattr__: Accessing attribute/method 'get_ts_subjs' across embeddings: found in ['pcomponents_ts', 'percentiles_ts', 'binheights_ts']
#  [DEBUG] embedding.get_ts_subjs: Getting time series for subjects for features p55
#  [DEBUG] embedding.get_ts_subjs: Available features: ['pc0', 'pc1', 'pc2', 'pc3', 'pc4']
#  [WARNING] embedding.get_ts_subjs_ftr: Feature p55 not in features: ['pc0', 'pc1', 'pc2', 'pc3', 'pc4']
#  [DEBUG] embedding.get_ts_subjs: Getting time series for subjects for features p55
#  [DEBUG] embedding.get_ts_subjs: Available features: ['p0', 'p5', 'p10', 'p15', 'p20', 'p25', 'p30', 'p35', 'p40', 'p45', 'p50', 'p55', 'p60', 'p65', 'p70', 'p75', 'p80', 'p85', 'p90', 'p95', 'p100']
#  [DEBUG] embedding.get_ts_subjs: Getting time series for subjects for features p55
# ...

# %% [markdown]
# #### A request for a list of percentiles returns a dictionary of dataframes

# %%
#| eval: false

percentile_emb.get_ts_subjs(['p50','p55'])
# Out:
#  [DEBUG] embedding.get_ts_subjs: Getting time series for subjects for features ['p50', 'p55']
#  [DEBUG] embedding.get_ts_subjs: Available features: ['p0', 'p5', 'p10', 'p15', 'p20', 'p25', 'p30', 'p35', 'p40', 'p45', 'p50', 'p55', 'p60', 'p65', 'p70', 'p75', 'p80', 'p85', 'p90', 'p95', 'p100']
# {'p50':         subj40     subj41     subj42     subj43     subj44     subj47  \
#  0    31.252890  32.008514  31.667484  32.511105  32.745951  32.861725
#  1    31.010395  32.016308  31.663542  32.514938  32.736443  32.861723
#  2    31.018439  31.992916  31.584604  32.491932  32.736443  32.861725
#  3    31.048591  32.004616  31.568792  32.511105  32.738344  32.857935
#  4    31.052611  31.992916  31.592506  32.495766  32.736441  32.854145
#  ..         ...        ...        ...        ...        ...        ...
#  995  31.732450  32.086380  31.754076  32.827610  32.747852  32.922272
#  996  31.732450  32.059151  31.742283  32.823814  32.764961  32.929832
# ...

# %% [markdown]
# #### Binheights
# > this type of embedding has binedges, which define the bin intervals. Bin intervals do not have to have the same width.

# %%
#| eval: false

bin_emb.binedges['subj66']
# Out:
# array([[27.018463, 27.336157],
#        [27.336157, 27.65385 ],
#        [27.65385 , 27.971544],
#        [27.971544, 28.289238],
#        [28.289238, 28.606934],
#        [28.606934, 28.924627],
#        [28.924627, 29.242321],
#        [29.242321, 29.560015],
#        [29.560015, 29.877708],
#        [29.877708, 30.195402],
#        [30.195402, 30.513096],
#        [30.513096, 30.83079 ],
#        [30.83079 , 31.148483],
#        [31.148483, 31.466177],
#        [31.466177, 31.78387 ],
#        [31.78387 , 32.101566],
#        [32.101566, 32.41926 ],
#        [32.41926 , 32.736954],
#        [32.736954, 33.054646],
#        [33.054646, 33.37234 ]], dtype=float32)

# %%
#| eval: false
combined_emb1.binedges['binheights_ts']['subj66']
# Out:
#  [DEBUG] embedding.__getattr__: Accessing attribute/method 'binedges' across embeddings: found in ['percentiles_ts', 'binheights_ts', 'pcomponents_ts']
# array([[27.018463, 27.336157],
#        [27.336157, 27.65385 ],
#        [27.65385 , 27.971544],
#        [27.971544, 28.289238],
#        [28.289238, 28.606934],
#        [28.606934, 28.924627],
#        [28.924627, 29.242321],
#        [29.242321, 29.560015],
#        [29.560015, 29.877708],
#        [29.877708, 30.195402],
#        [30.195402, 30.513096],
#        [30.513096, 30.83079 ],
#        [30.83079 , 31.148483],
#        [31.148483, 31.466177],
#        [31.466177, 31.78387 ],
#        [31.78387 , 32.101566],
#        [32.101566, 32.41926 ],
#        [32.41926 , 32.736954],
#        [32.736954, 33.054646],
#        [33.054646, 33.37234 ]], dtype=float32)

# %% [markdown]
# ## Plots

# %% [markdown]
# ### A projection to a chosen embedding component (`feature`)

# %% [markdown]
# #### Percentiles

# %%
#| eval: false

percentile_emb.plot_signal(
    subjs=[40,41],    # specify subject(s) to plot
    feature='p0'      # specify feature to plot (e.g., 'p0' for 0th percentile        
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'p0'}
#  [WARNING] py.warnings._showwarnmsg: /Users/radned/Projects/GitHub/fhemb/src/fhemb/embedding.py:576: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# (<Figure size 1200x400 with 2 Axes>,
#  [<Axes: title={'center': 'subj40: Frequency interval All Hz, period interval All s'}>,
# ...

# %%
#| eval: false
combined_emb1.plot_signal(
    subjs=[40,41],    # specify subject(s) to plot
    feature='p0'      # specify feature to plot (e.g., 'p0' for 0th percentile
)
# Out:
#  [DEBUG] embedding.__getattr__: Accessing attribute/method 'plot_signal' across embeddings: found in ['percentiles_ts', 'binheights_ts', 'pcomponents_ts']
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'p0'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
# ...

# %% [markdown]
# #### Eigenfaces

# %%
#| eval: false

pca_emb.plot_signal(
    subjs=[40,41],   # specify subject(s) to plot: may be specified also as intervals, e.g., [(40, 45), 47] 
    feature='pc2'    # specify feature to plot: principal components are prefixed by 'pc'    
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc2'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc2'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc2'}
# (<Figure size 1200x400 with 2 Axes>,
#  [<Axes: title={'center': 'subj40: Frequency interval All Hz, period interval All s'}>,
#   <Axes: title={'center': 'subj41: Frequency interval All Hz, period interval All s'}>])

# %%
#| eval: false

combined_emb1.plot_signal(
    subjs=[40,41],   # specify subject(s) to plot: may be specified also as intervals, e.g., [(40, 45), 47] 
    feature='pc2'    # specify feature to plot: principal components are prefixed by 'pc'
)
# Out:
#  [DEBUG] embedding.__getattr__: Accessing attribute/method 'plot_signal' across embeddings: found in ['percentiles_ts', 'binheights_ts', 'pcomponents_ts']
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc2'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc2'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc2'}
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc2'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
# ...

# %% [markdown]
# > Heatmap time series are embedded into eigenface coordinate system by projecting each heatmap onto the eigenface basis that can be visualized.

# %%
#| eval: false

pca_emb.visualize_eigenfaces(
    subjs=[40],       # specify subject(s) to plot: may be specified also as intervals, e.g., [(40, 45), 47] 
    components=[0,1]  # specify principle components, i.e., eigenfaces
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40], args=() and kwargs={}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
#  [DEBUG] mixins.wrapper: Calling: return_subjects with subjs=[40] and args=() and kwargs={}
#  [DEBUG] mixins.wrapper: Calling return_subjects with subjs=[40] and args=() and kwargs={}
#  [INFO] mixins.wrapper: Calling visualize_eigenfaces for subjects ['subj40'] and frequency bands []
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40], args=() and kwargs={'fbands': [], 'valid_subjects': ['subj40'], 'components': [0, 1]}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
# ...

# %% [markdown]
# > We can also visualize eigenfaces from a `Datasource` object with a nonstationary shape. Such a `Datasource`, like for example `facebbox_t`, must be "stationarized" by converting into `DatasourceResized` via `.rsfacebbox_t`.

# %%
#| eval: false

pca_emb_rs = dg0.facebbox_t.rsfacebbox_t.create_pca_embedding(factory=pca)[0]
# Out:
#  [INFO] piece._load_from_db: Loading facebbox_t from the database
#  [INFO] piece._fetch_from_DB: Fetching data by query SELECT subj40, subj41, subj42, subj43, subj44, subj47, subj48, subj49, subj50, subj51, subj52, subj53, subj54, subj56, subj57, subj58, subj59, subj60, subj61, subj62, subj63, subj64, subj65, subj66, subj67, subj68, subj69, subj70, subj71, subj73, subj74, subj75 FROM dg.faceposition_t WHERE frame_number >= 14200 AND frame_number < 15200 ORDER BY frame_number
#  [DEBUG] piece.start: SSH tunnel established
#  [DEBUG] piece.start: Effective DB params after start: dbname=tcamera user=tanalyst host=127.0.0.1 port=55004
#  [DEBUG] dbms.__enter__: Database connection opened: True (conn.closed=0)
#  [DEBUG] dbms.__enter__: Database cursor opened: True
# ...

# %%
#| eval: false

pca_emb_rs.plot_signal(
    subjs=[40,41],    # specify subject(s) to plot: may be specified also as intervals, e.g., [(40, 45), 47]  
    feature='pc2'     # specify feature to plot: principal components are prefixed by 'pc'    
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'feature': 'pc2'}
#  [DEBUG] mixins.wrapper: Getting subjects_int from self.subjects: ['subj40', 'subj41', 'subj42', 'subj43', 'subj44', 'subj47', 'subj48', 'subj49', 'subj50', 'subj51', 'subj52', 'subj53', 'subj54', 'subj56', 'subj57', 'subj58', 'subj59', 'subj60', 'subj61', 'subj62', 'subj63', 'subj64', 'subj65', 'subj66', 'subj67', 'subj68', 'subj69', 'subj70', 'subj71', 'subj73', 'subj74', 'subj75']
#  [DEBUG] mixins.wrapper: Calling: plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc2'}
#  [DEBUG] mixins.wrapper: Calling plot_signal with subjs=[40, 41] and args=() and kwargs={'feature': 'pc2'}
# ...

# %%
#| eval: false

pca_emb_rs.visualize_eigenfaces(
        subjs=[40],       # specify subject(s) to plot: may be specified also as intervals, e.g., [(40, 45), 47] 
        components=[0,1]  # specify principle components, i.e., eigenfaces
    )
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40], args=() and kwargs={}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
#  [DEBUG] mixins.wrapper: Calling: return_subjects with subjs=[40] and args=() and kwargs={}
#  [DEBUG] mixins.wrapper: Calling return_subjects with subjs=[40] and args=() and kwargs={}
#  [INFO] mixins.wrapper: Calling visualize_eigenfaces for subjects ['subj40'] and frequency bands []
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40], args=() and kwargs={'fbands': [], 'valid_subjects': ['subj40'], 'components': [0, 1]}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
# ...

# %% [markdown]
# ### Summaries of a binheight embedding (`bin_emb`) over chosen frames (`frms`)

# %%
#| eval: false

bin_emb.plot_temperaturebars(
    subjs=[40, 41],      # specify subject(s) to plot: may be specified also as intervals, e.g., [(40, 45), 47] 
    frms=[0,100,900],    # specify frame(s) to plot (e.g., [0, 100, 900])
    centralized=False    # specify whether to centralize the data (default: False): each bin around its own mean (centralized=True)     
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
#  [DEBUG] mixins.wrapper: Calling: return_subjects with subjs=[40, 41] and args=() and kwargs={}
#  [DEBUG] mixins.wrapper: Calling return_subjects with subjs=[40, 41] and args=() and kwargs={}
#  [INFO] mixins.wrapper: Calling plot_temperaturebars for subjects ['subj40', 'subj41'] and frequency bands []
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[40, 41], args=() and kwargs={'fbands': [], 'valid_subjects': ['subj40', 'subj41'], 'frms': [0, 100, 900], 'centralized': False}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
# ...

# %% [markdown]
# ### Summaries of a selected embedding (`normfacevec_t`) over chosen frames (`frms`)

# %%
#| eval:false

dg0.facebbox_t.rsfacebbox_t.normfacevec_ts.plot_temperaturehist(
    subjs=[40, 41],  # sspecify subject(s) to plot: may be specified also as intervals, e.g., [(40, 45), 47] 
    frms=[0,100,200] # specify frames to plot (e.g., [0, 100, 200]
)
# Out:
#  [INFO] piece._derive_features: Deriving binheights_ts, binedges, percentiles_ts, and features_ts
#  [DEBUG] piece._cache_derived_features: Creating binhieghts_ts Embedding
#  [DEBUG] embedding.__init__: Creating a BaseEmbedding with time_interval=(14200, 15200), subjects=None
#  [DEBUG] embedding.__init__: Subjects: ['subj40', 'subj41', 'subj42', 'subj43', 'subj44', 'subj47', 'subj48', 'subj49', 'subj50', 'subj51', 'subj52', 'subj53', 'subj54', 'subj56', 'subj57', 'subj58', 'subj59', 'subj60', 'subj61', 'subj62', 'subj63', 'subj64', 'subj65', 'subj66', 'subj67', 'subj68', 'subj69', 'subj70', 'subj71', 'subj73', 'subj74', 'subj75']
#  [DEBUG] embedding.__init__: No features provided, using all features from the first subject prefixed with bh
#  [DEBUG] piece._cache_derived_features: Creating binedges
#  [DEBUG] piece._cache_derived_features: Creating percentiles_ts Embedding
#  [DEBUG] embedding.__init__: Creating a BaseEmbedding with time_interval=(14200, 15200), subjects=None
# ...

# %% [markdown]
# ### A summary of a selected embedding component (`feature`) over a chosen frame interval (`intvl`)

# %%
#| eval: false

percentile_emb.plot_intvlhist(
    subjs=[41],        # specify subject(s) to plot: may be specified also as intervals, e.g., [(40, 45), 47] 
    intvl=(900,1000),  # specify interval of frames to plot (e.g., (900, 1000))
    feature='p90'      # specify feature to plot (e.g., 'p90' for 90th percentile
)
# Out:
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[41], args=() and kwargs={}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
#  [DEBUG] mixins.wrapper: Calling: return_subjects with subjs=[41] and args=() and kwargs={}
#  [DEBUG] mixins.wrapper: Calling return_subjects with subjs=[41] and args=() and kwargs={}
#  [INFO] mixins.wrapper: Calling plot_intvlhist for subjects ['subj41'] and frequency bands []
#  [DEBUG] mixins.wrapper: wrapper of process_subjects called with subjs=[41], args=() and kwargs={'fbands': [], 'valid_subjects': ['subj41'], 'intvl': (900, 1000), 'feature': 'p90'}
#  [DEBUG] mixins.wrapper: Using self.subjects_int: [40, 41, 42, 43, 44, 47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 74, 75]
# ...
